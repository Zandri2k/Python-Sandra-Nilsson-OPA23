# %%
text_path = "../data/pikachu.txt"  #hämtar ut filer utanför sin egen map


with open(text_path, "r") as file:
    data_text = file.read()

print(data_text)
# Out:
# (width (cm), height (cm))
# (18.137772263313835, 44.951493566608946)
# (26.648661832322336, 41.49878057639454)
# (26.180524428318897, 39.38100083914504)
# (24.44364396490554, 40.175758410355904)
# (21.201902279430513, 36.21004195868266)
# (25.691541582957697, 37.24697337031557)
# (19.338626083150515, 38.38085562147455)
# (23.21718300802926, 40.88308718457233)
# (23.444684475950478, 37.30114732596577)
# (29.445791130252964, 37.20217384451559)
# (28.51023528453833, 35.709930860090324)
# (21.16066860901309, 41.31102957270099)
# (24.00703335660358, 37.28941783811155)
# (20.143822566361578, 44.054200130061275)
# (28.951534072137846, 43.59635400253747)
# (28.4462228380412, 35.70857349888654)
# (21.581337497383593, 37.380046343689955)
# (25.66739393839206, 41.68977778296281)
# (25.30764253725807, 37.14236807370439)
# (19.834071222595618, 36.32311848725025)
# (27.150129600901813, 44.35514240580671)
# (24.472548361435507, 40.710430933252844)
# (27.3435177435667, 39.726710263117944)
# ...

# %%
data = data_text.split("\n")[1:-1]

data[0]
# Out:
# '(18.137772263313835, 44.951493566608946)'

# %%
eval(data[0])
# Out:
# (18.137772263313835, 44.951493566608946)

# %%
data2 = []
for point in data: 
    data2.append(eval(point)) #omvandlas till siffror

print(data2)
# Out:
# [(18.137772263313835, 44.951493566608946), (26.648661832322336, 41.49878057639454), (26.180524428318897, 39.38100083914504), (24.44364396490554, 40.175758410355904), (21.201902279430513, 36.21004195868266), (25.691541582957697, 37.24697337031557), (19.338626083150515, 38.38085562147455), (23.21718300802926, 40.88308718457233), (23.444684475950478, 37.30114732596577), (29.445791130252964, 37.20217384451559), (28.51023528453833, 35.709930860090324), (21.16066860901309, 41.31102957270099), (24.00703335660358, 37.28941783811155), (20.143822566361578, 44.054200130061275), (28.951534072137846, 43.59635400253747), (28.4462228380412, 35.70857349888654), (21.581337497383593, 37.380046343689955), (25.66739393839206, 41.68977778296281), (25.30764253725807, 37.14236807370439), (19.834071222595618, 36.32311848725025), (27.150129600901813, 44.35514240580671), (24.472548361435507, 40.710430933252844), (27.3435177435667, 39.726710263117944), (24.36424406634213, 42.846194242907536), (18.0068627535353
# ...

# %%
data2[0]
# Out:
# (18.137772263313835, 44.951493566608946)

# %%
text2_path = "../data/pichu.txt"  #hämtar ut filer utanför sin egen map


with open(text2_path, "r") as file:
    data3_text = file.read()

print(data3_text)
# Out:
# (width (cm), height (cm))
# (20.11541438766307, 28.701809671168824)
# (15.200086041781336, 27.095070307714877)
# (17.200234546952956, 27.669778220491132)
# (16.785685905190583, 34.36654587712494)
# (20.8917697133121, 31.480353852465935)
# (20.41359589938329, 31.091310056669883)
# (22.137436541638763, 26.71138648198097)
# (15.695510661035328, 32.291267979503495)
# (18.375374557482164, 26.634024937619284)
# (15.238377755504562, 28.794554417576478)
# (16.749103798428827, 34.895233506365955)
# (19.042842304826898, 31.399997598540928)
# (15.212287757470909, 30.569497437746463)
# (16.59070120549319, 31.846142509898748)
# (20.199075502236184, 33.4285192018981)
# (19.35953184482573, 32.75999911546245)
# (16.763524976325574, 27.290480719641042)
# (19.71412547100727, 25.321002439040377)
# (21.475443653422612, 28.154530480590818)
# (15.051990077424488, 27.67740875975703)
# (21.446554014662464, 27.109828435863264)
# (20.585115159905815, 34.429097143350546)
# ...

# %%
data3 = data3_text.split("\n")[1:-1]
len(data3)
# Out:
# 50

# %%
eval(data3[0])
# Out:
# (20.11541438766307, 28.701809671168824)

# %%
data3_list = []
for point in data3:
    data3_list.append(eval(point)) #omvandlas till siffror

print(data3_list)
# Out:
# [(20.11541438766307, 28.701809671168824), (15.200086041781336, 27.095070307714877), (17.200234546952956, 27.669778220491132), (16.785685905190583, 34.36654587712494), (20.8917697133121, 31.480353852465935), (20.41359589938329, 31.091310056669883), (22.137436541638763, 26.71138648198097), (15.695510661035328, 32.291267979503495), (18.375374557482164, 26.634024937619284), (15.238377755504562, 28.794554417576478), (16.749103798428827, 34.895233506365955), (19.042842304826898, 31.399997598540928), (15.212287757470909, 30.569497437746463), (16.59070120549319, 31.846142509898748), (20.199075502236184, 33.4285192018981), (19.35953184482573, 32.75999911546245), (16.763524976325574, 27.290480719641042), (19.71412547100727, 25.321002439040377), (21.475443653422612, 28.154530480590818), (15.051990077424488, 27.67740875975703), (21.446554014662464, 27.109828435863264), (20.585115159905815, 34.429097143350546), (17.722004132143937, 33.76367626472669), (16.24383599849425, 28.14677880798478), (22.6
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data2 = np.array (data2)

data2[:5]
# Out:
# array([[18.13777226, 44.95149357],
#        [26.64866183, 41.49878058],
#        [26.18052443, 39.38100084],
#        [24.44364396, 40.17575841],
#        [21.20190228, 36.21004196]])

# %%
data2[:,0]
# Out:
# array([18.13777226, 26.64866183, 26.18052443, 24.44364396, 21.20190228,
#        25.69154158, 19.33862608, 23.21718301, 23.44468448, 29.44579113,
#        28.51023528, 21.16066861, 24.00703336, 20.14382257, 28.95153407,
#        28.44622284, 21.5813375 , 25.66739394, 25.30764254, 19.83407122,
#        27.1501296 , 24.47254836, 27.34351774, 24.36424407, 18.00686275,
#        21.88987268, 18.23372091, 29.1491834 , 28.54466253, 27.97998635,
#        21.6901695 , 18.695102  , 28.53611519, 29.36339334, 19.02784142,
#        23.83188556, 18.83055022, 27.12722598, 27.19001315, 19.54069757,
#        23.70338854, 24.59764312, 21.18067955, 28.46919649, 23.07765528,
#        20.54157847, 24.47155307, 26.75917283, 20.41381276, 21.7405955 ])

# %%
data3_list = np.array(data3_list)

data3_list[:5]
# Out:
# array([[20.11541439, 28.70180967],
#        [15.20008604, 27.09507031],
#        [17.20023455, 27.66977822],
#        [16.78568591, 34.36654588],
#        [20.89176971, 31.48035385]])

# %% [markdown]
# # Ploting av Pikachu och Pichus värden

# %%
plt.plot(data2[:,0],data2[:,1], "ro") #plottar data2 x och y axel
plt.plot(data3_list[:,0], data3_list[:,1], "go")
# plt.plot(data3[:,0], data3[:,1] "x")
plt.xlabel('Width') 
plt.ylabel('Height') 
plt.legend(["Pikachu", "Pichu"],)

# kolla omvandlingen för data3 something is off
# eucleandean distance

# %% [markdown]
# # Importering av testpunkter

# %%
text_path = "../data/test_points.txt"  


with open(text_path, "r") as file:
    test_point = file.read()


print(test_point)
# Out:
# (25, 35), (15,14), (26,30), (22,45)

# %%
f"[{test_point}]"  # en string i lista av tuples
# Out:
# '[(25, 35), (15,14), (26,30), (22,45)]'

# %%
eval(f"[{test_point}]")  #lista av tuples
# Out:
# [(25, 35), (15, 14), (26, 30), (22, 45)]

# %%
test_points = eval(f"[{test_point}]") # tuples sparad i en ny variable

# %%
test_points[0]
# Out:
# (25, 35)

# %%
import numpy as np
test_points = np.array(test_points)

# %%
plt.plot(data2[:,0],data2[:,1], "ro") #plottar data2 x och y axel
plt.plot(data3_list[:,0], data3_list[:,1], "go")
plt.plot(test_points[:, 0], test_points[:, 1], "bo")
# plt.plot(data3[:,0], data3[:,1] "x")
plt.xlabel('Width') 
plt.ylabel('Height') 

plt.legend(["Pikachu", "Pichu", "test_point"],)

# %% [markdown]
# # Merge the lists

# %%
merged_data = []
for point in data3_list:
    merged_data.append(point)

for point in data2:
    merged_data.append(point)

print(merged_data)
# Out:
# [array([20.11541439, 28.70180967]), array([15.20008604, 27.09507031]), array([17.20023455, 27.66977822]), array([16.78568591, 34.36654588]), array([20.89176971, 31.48035385]), array([20.4135959 , 31.09131006]), array([22.13743654, 26.71138648]), array([15.69551066, 32.29126798]), array([18.37537456, 26.63402494]), array([15.23837776, 28.79455442]), array([16.7491038 , 34.89523351]), array([19.0428423, 31.3999976]), array([15.21228776, 30.56949744]), array([16.59070121, 31.84614251]), array([20.1990755, 33.4285192]), array([19.35953184, 32.75999912]), array([16.76352498, 27.29048072]), array([19.71412547, 25.32100244]), array([21.47544365, 28.15453048]), array([15.05199008, 27.67740876]), array([21.44655401, 27.10982844]), array([20.58511516, 34.42909714]), array([17.72200413, 33.76367626]), array([16.243836  , 28.14677881]), array([22.65770458, 31.55438665]), array([17.69275636, 28.95631901]), array([15.74196675, 34.1454759 ]), array([15.77373101, 29.58851853]), array([21.77995493, 2
# ...

# %%
len(merged_data) #checking that the lengh of the list is accurate (it is) :3
# Out:
# 100

# %%
merged_data[8]
# Out:
# array([18.37537456, 26.63402494])

# %%
import numpy as np

# %% [markdown]
# # skapar Lables
# - Skapar labels till data3_list(pikachu) och data2(pichu)
# - np.ones(len(data3_list)) sätter värdet 1 vid varje punkt som är pikachu
# - np.zeros(len(data2)) sätter värdet 0 vid  varje punkt som är en pichu

# %%
labels_data3 = np.ones(len(data3_list))
labels_data2 = np.zeros(len(data2))
labels = np.concatenate((labels_data3, labels_data2))
merged_data_with_labels =[(x, y, label) for (x, y), label in zip(merged_data,labels)]
merged_data_with_labels = [(x, y, label) for (x, y), label in zip(merged_data, labels)]
print(merged_data_with_labels)
# Out:
# [(20.11541438766307, 28.701809671168824, 1.0), (15.200086041781336, 27.095070307714877, 1.0), (17.200234546952956, 27.669778220491132, 1.0), (16.785685905190583, 34.36654587712494, 1.0), (20.8917697133121, 31.480353852465935, 1.0), (20.41359589938329, 31.091310056669883, 1.0), (22.137436541638763, 26.71138648198097, 1.0), (15.695510661035328, 32.291267979503495, 1.0), (18.375374557482164, 26.634024937619284, 1.0), (15.238377755504562, 28.794554417576478, 1.0), (16.749103798428827, 34.895233506365955, 1.0), (19.042842304826898, 31.399997598540928, 1.0), (15.212287757470909, 30.569497437746463, 1.0), (16.59070120549319, 31.846142509898748, 1.0), (20.199075502236184, 33.4285192018981, 1.0), (19.35953184482573, 32.75999911546245, 1.0), (16.763524976325574, 27.290480719641042, 1.0), (19.71412547100727, 25.321002439040377, 1.0), (21.475443653422612, 28.154530480590818, 1.0), (15.051990077424488, 27.67740875975703, 1.0), (21.446554014662464, 27.109828435863264, 1.0), (20.585115159905815, 34
# ...

# %%
merged_data_with_labels[89]
# Out:
# (19.540697573997154, 39.48613547833132, 0.0)

# %%
merged_data_with_labels[2]
# Out:
# (17.200234546952956, 27.669778220491132, 1.0)

# %%
merged_data_with_labels = np.array(merged_data_with_labels) #transformed to numpy array pga prep for slicing

# %%
test_points = np.array(test_points)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 te
#
# NameError: name 'te' is not defined
